# %% [markdown]
# <a href="https://colab.research.google.com/github/Firyal-16/UAS-PPh-Badan/blob/main/Tax_Revenue_pct_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Data for tax_revenue_pct_gdp
tax_revenue_pct_gdp_data = [
    {'tahun': 2023, 'tax_revenue_pct_gdp': 152.1799926758, 'country': 'Croatia', 'country_code_3': 'HRV'},
    {'tahun': 2023, 'tax_revenue_pct_gdp': 44.3468017578, 'country': 'Nauru', 'country_code_3': 'NRU'},
    {'tahun': 2023, 'tax_revenue_pct_gdp': 35.4556007385, 'country': 'Denmark', 'country_code_3': 'DNK'},
    {'tahun': 2023, 'tax_revenue_pct_gdp': 32.4802017212, 'country': 'Seychelles', 'country_code_3': 'SYC'},
    {'tahun': 2023, 'tax_revenue_pct_gdp': 32.3900985718, 'country': 'Lesotho', 'country_code_3': 'LSO'},
    {'tahun': 2023, 'tax_revenue_pct_gdp': 28.8432006836, 'country': 'New Zealand', 'country_code_3': 'NZL'},
    {'tahun': 2023, 'tax_revenue_pct_gdp': 27.9652004242, 'country': 'Namibia', 'country_code_3': 'NAM'},
    {'tahun': 2023, 'tax_revenue_pct_gdp': 27.4785003662, 'country': 'Barbados', 'country_code_3': 'BRB'},
    {'tahun': 2023, 'tax_revenue_pct_gdp': 27.3756008148, 'country': 'Kiribati', 'country_code_3': 'KIR'},
    {'tahun': 2023, 'tax_revenue_pct_gdp': 27.3367996216, 'country': 'Sweden', 'country_code_3': 'SWE'},
    {'tahun': 2023, 'tax_revenue_pct_gdp': 26.3806991577, 'country': 'United Kingdom', 'country_code_3': 'GBR'},
    {'tahun': 2023, 'tax_revenue_pct_gdp': 26.1380996704, 'country': 'Luxembourg', 'country_code_3': 'LUX'},
    {'tahun': 2023, 'tax_revenue_pct_gdp': 25.9158000946, 'country': 'South Africa', 'country_code_3': 'ZAF'},
    {'tahun': 2023, 'tax_revenue_pct_gdp': 25.783000946, 'country': 'Austria', 'country_code_3': 'AUT'},
    {'tahun': 2023, 'tax_revenue_pct_gdp': 25.7469005585, 'country': 'Norway', 'country_code_3': 'NOR'},
    {'tahun': 2023, 'tax_revenue_pct_gdp': 25.7094993591, 'country': 'Jamaica', 'country_code_3': 'JAM'},
    {'tahun': 2023, 'tax_revenue_pct_gdp': 25.4104995728, 'country': 'Italy', 'country_code_3': 'ITA'},
    {'tahun': 2023, 'tax_revenue_pct_gdp': 25.3409004211, 'country': 'Greece', 'country_code_3': 'GRC'},
    {'tahun': 2023, 'tax_revenue_pct_gdp': 25.0244998932, 'country': 'Samoa', 'country_code_3': 'WSM'},
    {'tahun': 2023, 'tax_revenue_pct_gdp': 24.7812004089, 'country': 'Netherlands', 'country_code_3': 'NLD'},
    {'tahun': 2023, 'tax_revenue_pct_gdp': 24.6154003143, 'country': 'Israel', 'country_code_3': 'ISR'},
    {'tahun': 2023, 'tax_revenue_pct_gdp': 24.2325992584, 'country': 'Malta', 'country_code_3': 'MLT'},
    {'tahun': 2023, 'tax_revenue_pct_gdp': 24.1123008728, 'country': 'Cyprus', 'country_code_3': 'CYP'},
    {'tahun': 2023, 'tax_revenue_pct_gdp': 23.9682998657, 'country': 'France', 'country_code_3': 'FRA'},
    {'tahun': 2023, 'tax_revenue_pct_gdp': 23.7996006012, 'country': 'St. Vincent and the Grenadines', 'country_code_3': 'VCT'},
    {'tahun': 2023, 'tax_revenue_pct_gdp': 23.3495006561, 'country': 'Belgium', 'country_code_3': 'BEL'},
    {'tahun': 2023, 'tax_revenue_pct_gdp': 23.3120002747, 'country': 'Mozambique', 'country_code_3': 'MOZ'},
    {'tahun': 2023, 'tax_revenue_pct_gdp': 23.1275005341, 'country': 'Australia', 'country_code_3': 'AUS'},
    {'tahun': 2023, 'tax_revenue_pct_gdp': 22.2460002899, 'country': 'Botswana', 'country_code_3': 'BWA'},
    {'tahun': 2023, 'tax_revenue_pct_gdp': 22.140499115, 'country': 'Portugal', 'country_code_3': 'PRT'},
    {'tahun': 2023, 'tax_revenue_pct_gdp': 22.028799057, 'country': 'Armenia', 'country_code_3': 'ARM'},
    {'tahun': 2023, 'tax_revenue_pct_gdp': 21.7668991089, 'country': 'Latvia', 'country_code_3': 'LVA'},
    {'tahun': 2023, 'tax_revenue_pct_gdp': 21.7308006287, 'country': 'Georgia', 'country_code_3': 'GEO'},
    {'tahun': 2023, 'tax_revenue_pct_gdp': 21.6184005737, 'country': 'Iceland', 'country_code_3': 'ISL'},
    {'tahun': 2023, 'tax_revenue_pct_gdp': 21.4745998383, 'country': 'West Bank and Gaza', 'country_code_3': 'PSE'},
    {'tahun': 2023, 'tax_revenue_pct_gdp': 21.463300705, 'country': 'Hungary', 'country_code_3': 'HUN'},
    {'tahun': 2023, 'tax_revenue_pct_gdp': 21.4246997833, 'country': 'Estonia', 'country_code_3': 'EST'},
    {'tahun': 2023, 'tax_revenue_pct_gdp': 21.393699646, 'country': 'Lithuania', 'country_code_3': 'LTU'},
    {'tahun': 2023, 'tax_revenue_pct_gdp': 21.160200119, 'country': 'Belize', 'country_code_3': 'BLZ'},
    {'tahun': 2023, 'tax_revenue_pct_gdp': 20.6681003571, 'country': 'Solomon Islands', 'country_code_3': 'SLB'},
    {'tahun': 2023, 'tax_revenue_pct_gdp': 20.6553001404, 'country': 'Finland', 'country_code_3': 'FIN'},
    {'tahun': 2023, 'tax_revenue_pct_gdp': 20.6212997437, 'country': 'Bulgaria', 'country_code_3': 'BGR'},
    {'tahun': 2023, 'tax_revenue_pct_gdp': 20.620300293, 'country': 'Serbia', 'country_code_3': 'SRB'},
    {'tahun': 2023, 'tax_revenue_pct_gdp': 20.1154994965, 'country': 'Tunisia', 'country_code_3': 'TUN'},
    {'tahun': 2023, 'tax_revenue_pct_gdp': 19.5981998444, 'country': 'Chile', 'country_code_3': 'CHL'},
    {'tahun': 2023, 'tax_revenue_pct_gdp': 19.5489997864, 'country': 'Morocco', 'country_code_3': 'MAR'},
    {'tahun': 2023, 'tax_revenue_pct_gdp': 19.5188007355, 'country': 'Trinidad and Tobago', 'country_code_3': 'TTO'},
    {'tahun': 2023, 'tax_revenue_pct_gdp': 19.4167995453, 'country': 'El Salvador', 'country_code_3': 'SLV'},
    {'tahun': 2023, 'tax_revenue_pct_gdp': 19.289100647, 'country': 'Slovak Republic', 'country_code_3': 'SVK'},
    {'tahun': 2023, 'tax_revenue_pct_gdp': 19.2052993774, 'country': 'Poland', 'country_code_3': 'POL'},
    {'tahun': 2023, 'tax_revenue_pct_gdp': 19.1168003082, 'country': 'Bosnia and Herzegovina', 'country_code_3': 'BIH'},
    {'tahun': 2023, 'tax_revenue_pct_gdp': 19.0823001862, 'country': 'Ukraine', 'country_code_3': 'UKR'},
    {'tahun': 2023, 'tax_revenue_pct_gdp': 18.904800415, 'country': 'Nicaragua', 'country_code_3': 'NIC'},
    {'tahun': 2023, 'tax_revenue_pct_gdp': 18.5898990631, 'country': 'Palau', 'country_code_3': 'PLW'},
    {'tahun': 2023, 'tax_revenue_pct_gdp': 18.515499115, 'country': 'Uruguay', 'country_code_3': 'URY'},
    {'tahun': 2023, 'tax_revenue_pct_gdp': 18.3880996704, 'country': 'Moldova', 'country_code_3': 'MDA'},
    {'tahun': 2023, 'tax_revenue_pct_gdp': 18.2954998016, 'country': 'Slovenia', 'country_code_3': 'SVN'},
    {'tahun': 2023, 'tax_revenue_pct_gdp': 18.2770004272, 'country': 'Mauritius', 'country_code_3': 'MUS'},
    {'tahun': 2023, 'tax_revenue_pct_gdp': 18.2415008545, 'country': 'St. Lucia', 'country_code_3': 'LCA'},
    {'tahun': 2023, 'tax_revenue_pct_gdp': 18.2047996521, 'country': 'The Gambia', 'country_code_3': 'GMB'},
    {'tahun': 2023, 'tax_revenue_pct_gdp': 18.198600769, 'country': 'Albania', 'country_code_3': 'ALB'},
    {'tahun': 2023, 'tax_revenue_pct_gdp': 17.8817996979, 'country': 'Turkey', 'country_code_3': 'TUR'},
    {'tahun': 2023, 'tax_revenue_pct_gdp': 17.8036003113, 'country': 'Cabo Verde', 'country_code_3': 'CPV'},
    {'tahun': 2023, 'tax_revenue_pct_gdp': 17.611000061, 'country': 'North Macedonia', 'country_code_3': 'MKD'},
    {'tahun': 2023, 'tax_revenue_pct_gdp': 17.5193996429, 'country': 'Senegal', 'country_code_3': 'SEN'},
    {'tahun': 2023, 'tax_revenue_pct_gdp': 17.4853000641, 'country': 'Nepal', 'country_code_3': 'NPL'},
    {'tahun': 2023, 'tax_revenue_pct_gdp': 17.4769001007, 'country': 'Ireland', 'country_code_3': 'IRL'},
    {'tahun': 2023, 'tax_revenue_pct_gdp': 17.4505996704, 'country': 'Kyrgyz Republic', 'country_code_3': 'KGZ'},
    {'tahun': 2023, 'tax_revenue_pct_gdp': 17.295999527, 'country': 'San Marino', 'country_code_3': 'SMR'},
    {'tahun': 2023, 'tax_revenue_pct_gdp': 17.1609992981, 'country': 'Marshall Islands', 'country_code_3': 'MHL'},
    {'tahun': 2023, 'tax_revenue_pct_gdp': 16.9648990631, 'country': 'Bolivia', 'country_code_3': 'BOL'},
    {'tahun': 2023, 'tax_revenue_pct_gdp': 16.9088001251, 'country': 'Mongolia', 'country_code_3': 'MNG'},
    {'tahun': 2023, 'tax_revenue_pct_gdp': 16.8036994934, 'country': 'Korea', 'country_code_3': 'KOR'},
    {'tahun': 2023, 'tax_revenue_pct_gdp': 16.7416000366, 'country': 'Zambia', 'country_code_3': 'ZMB'},
    {'tahun': 2023, 'tax_revenue_pct_gdp': 16.364900589, 'country': 'Cambodia', 'country_code_3': 'KHM'},
    {'tahun': 2023, 'tax_revenue_pct_gdp': 16.110200882, 'country': 'Peru', 'country_code_3': 'PER'},
    {'tahun': 2023, 'tax_revenue_pct_gdp': 16.0252990723, 'country': 'Jordan', 'country_code_3': 'JOR'},
    {'tahun': 2023, 'tax_revenue_pct_gdp': 15.9067001343, 'country': 'Fiji', 'country_code_3': 'FJI'},
    {'tahun': 2023, 'tax_revenue_pct_gdp': 15.9064998627, 'country': 'Burkina Faso', 'country_code_3': 'BFA'},
    {'tahun': 2023, 'tax_revenue_pct_gdp': 15.2250003815, 'country': 'Spain', 'country_code_3': 'ESP'},
    {'tahun': 2023, 'tax_revenue_pct_gdp': 15.1034002304, 'country': 'Timor-Leste', 'country_code_3': 'TLS'},
    {'tahun': 2023, 'tax_revenue_pct_gdp': 15.0766000748, 'country': 'Rwanda', 'country_code_3': 'RWA'},
    {'tahun': 2023, 'tax_revenue_pct_gdp': 15.0321998596, 'country': 'St. Kitts and Nevis', 'country_code_3': 'KNA'},
    {'tahun': 2023, 'tax_revenue_pct_gdp': 14.9850997925, 'country': 'Romania', 'country_code_3': 'ROU'},
    {'tahun': 2023, 'tax_revenue_pct_gdp': 14.785900116, 'country': 'Uzbekistan', 'country_code_3': 'UZB'},
    {'tahun': 2023, 'tax_revenue_pct_gdp': 14.7653999329, 'country': 'Honduras', 'country_code_3': 'HND'},
    {'tahun': 2023, 'tax_revenue_pct_gdp': 14.443400383, 'country': 'Colombia', 'country_code_3': 'COL'},
    {'tahun': 2023, 'tax_revenue_pct_gdp': 14.3774003983, 'country': 'Dominican Republic', 'country_code_3': 'DOM'},
    {'tahun': 2023, 'tax_revenue_pct_gdp': 14.3240995407, 'country': 'Thailand', 'country_code_3': 'THA'},
    {'tahun': 2023, 'tax_revenue_pct_gdp': 14.3168001175, 'country': 'Brazil', 'country_code_3': 'BRA'},
    {'tahun': 2023, 'tax_revenue_pct_gdp': 14.1645002365, 'country': 'Mali', 'country_code_3': 'MLI'},
    {'tahun': 2023, 'tax_revenue_pct_gdp': 14.1300001144, 'country': 'Philippines', 'country_code_3': 'PHL'},
    {'tahun': 2023, 'tax_revenue_pct_gdp': 14.073800087, 'country': 'Costa Rica', 'country_code_3': 'CRI'},
    {'tahun': 2023, 'tax_revenue_pct_gdp': 14.0403003693, 'country': 'Vanuatu', 'country_code_3': 'VUT'},
    {'tahun': 2023, 'tax_revenue_pct_gdp': 13.9812002182, 'country': 'The Bahamas', 'country_code_3': 'BHS'},
    {'tahun': 2023, 'tax_revenue_pct_gdp': 13.8719997406, 'country': 'Mexico', 'country_code_3': 'MEX'},
    {'tahun': 2023, 'tax_revenue_pct_gdp': 13.5973997116, 'country': 'Burundi', 'country_code_3': 'BDI'},
    {'tahun': 2023, 'tax_revenue_pct_gdp': 13.5836000443, 'country': 'Togo', 'country_code_3': 'TGO'},
    {'tahun': 2023, 'tax_revenue_pct_gdp': 13.4212999344, 'country': 'Azerbaijan', 'country_code_3': 'AZE'},
    {'tahun': 2023, 'tax_revenue_pct_gdp': 13.361000061, 'country': 'Czech Republic', 'country_code_3': 'CZE'},
    {'tahun': 2023, 'tax_revenue_pct_gdp': 13.2649002075, 'country': 'Kenya', 'country_code_3': 'KEN'},
    {'tahun': 2023, 'tax_revenue_pct_gdp': 13.2594003677, 'country': 'Canada', 'country_code_3': 'CAN'},
    {'tahun': 2023, 'tax_revenue_pct_gdp': 13.1246995926, 'country': 'Singapore', 'country_code_3': 'SGP'},
    {'tahun': 2023, 'tax_revenue_pct_gdp': 12.9841995239, 'country': 'Bhutan', 'country_code_3': 'BTN'},
    {'tahun': 2023, 'tax_revenue_pct_gdp': 12.8573999405, 'country': 'Ecuador', 'country_code_3': 'ECU'},
    {'tahun': 2023, 'tax_revenue_pct_gdp': 12.5591001511, 'country': 'Côte d''Ivoire', 'country_code_3': 'CIV'},
    {'tahun': 2023, 'tax_revenue_pct_gdp': 12.519200325, 'country': 'Egypt', 'country_code_3': 'EGY'},
    {'tahun': 2023, 'tax_revenue_pct_gdp': 12.461400032, 'country': 'Liberia', 'country_code_3': 'LBR'},
    {'tahun': 2023, 'tax_revenue_pct_gdp': 12.4589004517, 'country': 'Uganda', 'country_code_3': 'UGA'},
    {'tahun': 2023, 'tax_revenue_pct_gdp': 12.0228996277, 'country': 'Belarus', 'country_code_3': 'BLR'},
    {'tahun': 2023, 'tax_revenue_pct_gdp': 12.0173997879, 'country': 'India', 'country_code_3': 'IND'},
    {'tahun': 2023, 'tax_revenue_pct_gdp': 11.8791999817, 'country': 'Papua New Guinea', 'country_code_3': 'PNG'},
    {'tahun': 2023, 'tax_revenue_pct_gdp': 11.7644996643, 'country': 'Niger', 'country_code_3': 'NER'},
    {'tahun': 2023, 'tax_revenue_pct_gdp': 11.6950998306, 'country': 'Tanzania', 'country_code_3': 'TZA'},
    {'tahun': 2023, 'tax_revenue_pct_gdp': 11.647600174, 'country': 'Russia', 'country_code_3': 'RUS'},
    {'tahun': 2023, 'tax_revenue_pct_gdp': 11.6129999161, 'country': 'Guatemala', 'country_code_3': 'GTM'},
    {'tahun': 2023, 'tax_revenue_pct_gdp': 11.5908002853, 'country': 'Japan', 'country_code_3': 'JPN'},
    {'tahun': 2023, 'tax_revenue_pct_gdp': 11.4843997955, 'country': 'Argentina', 'country_code_3': 'ARG'},
    {'tahun': 2023, 'tax_revenue_pct_gdp': 11.4794998169, 'country': 'Gabon', 'country_code_3': 'GAB'},
    {'tahun': 2023, 'tax_revenue_pct_gdp': 11.3816003799, 'country': 'Malawi', 'country_code_3': 'MWI'},
    {'tahun': 2023, 'tax_revenue_pct_gdp': 11.3403997421, 'country': 'Ghana', 'country_code_3': 'GHA'},
    {'tahun': 2023, 'tax_revenue_pct_gdp': 11.2402000427, 'country': 'Malaysia', 'country_code_3': 'MYS'},
    {'tahun': 2023, 'tax_revenue_pct_gdp': 11.2335996628, 'country': 'United States', 'country_code_3': 'USA'},
    {'tahun': 2023, 'tax_revenue_pct_gdp': 11.2252998352, 'country': 'Germany', 'country_code_3': 'DEU'},
    {'tahun': 2023, 'tax_revenue_pct_gdp': 10.8705997467, 'country': 'Cameroon', 'country_code_3': 'CMR'},
    {'tahun': 2023, 'tax_revenue_pct_gdp': 10.841799736, 'country': 'Guinea', 'country_code_3': 'GIN'},
    {'tahun': 2023, 'tax_revenue_pct_gdp': 10.7890996933, 'country': 'Benin', 'country_code_3': 'BEN'},
    {'tahun': 2023, 'tax_revenue_pct_gdp': 10.7040996552, 'country': 'Dem. Rep. Congo', 'country_code_3': 'COD'},
    {'tahun': 2023, 'tax_revenue_pct_gdp': 10.254699707, 'country': 'Switzerland', 'country_code_3': 'CHE'},
    {'tahun': 2023, 'tax_revenue_pct_gdp': 10.2384996414, 'country': 'Madagascar', 'country_code_3': 'MDG'},
    {'tahun': 2023, 'tax_revenue_pct_gdp': 10.0903997421, 'country': 'Angola', 'country_code_3': 'AGO'},
    {'tahun': 2023, 'tax_revenue_pct_gdp': 9.8984498978, 'country': 'Afghanistan', 'country_code_3': 'AFG'},
    {'tahun': 2023, 'tax_revenue_pct_gdp': 9.8210201263, 'country': 'Tajikistan', 'country_code_3': 'TJK'},
    {'tahun': 2023, 'tax_revenue_pct_gdp': 9.7942495346, 'country': 'Paraguay', 'country_code_3': 'PRY'},
    {'tahun': 2023, 'tax_revenue_pct_gdp': 9.4620704651, 'country': 'Guinea-Bissau', 'country_code_3': 'GNB'},
    {'tahun': 2023, 'tax_revenue_pct_gdp': 9.4471101761, 'country': 'Kazakhstan', 'country_code_3': 'KAZ'},
    {'tahun': 2023, 'tax_revenue_pct_gdp': 9.1070804596, 'country': 'Congo', 'country_code_3': 'COG'},
    {'tahun': 2023, 'tax_revenue_pct_gdp': 9.1006698608, 'country': 'Maldives', 'country_code_3': 'MDV'},
    {'tahun': 2023, 'tax_revenue_pct_gdp': 9.0968704224, 'country': 'Pakistan', 'country_code_3': 'PAK'},
    {'tahun': 2023, 'tax_revenue_pct_gdp': 9.094039917, 'country': 'Indonesia', 'country_code_3': 'IDN'},
    {'tahun': 2023, 'tax_revenue_pct_gdp': 8.2374696732, 'country': 'Saudi Arabia', 'country_code_3': 'SAU'},
    {'tahun': 2023, 'tax_revenue_pct_gdp': 8.2062902451, 'country': 'Central African Republic', 'country_code_3': 'CAF'},
    {'tahun': 2023, 'tax_revenue_pct_gdp': 8.0906295776, 'country': 'China', 'country_code_3': 'CHN'},
    {'tahun': 2023, 'tax_revenue_pct_gdp': 8.0461797714, 'country': 'Panama', 'country_code_3': 'PAN'},
    {'tahun': 2023, 'tax_revenue_pct_gdp': 7.6423602104, 'country': 'Bangladesh', 'country_code_3': 'BGD'},
    {'tahun': 2023, 'tax_revenue_pct_gdp': 7.3902702332, 'country': 'Sudan', 'country_code_3': 'SDN'},
    {'tahun': 2023, 'tax_revenue_pct_gdp': 7.3750300407, 'country': 'Sri Lanka', 'country_code_3': 'LKA'},
    {'tahun': 2023, 'tax_revenue_pct_gdp': 7.3584799767, 'country': 'Iran', 'country_code_3': 'IRN'},
    {'tahun': 2023, 'tax_revenue_pct_gdp': 7.2147698402, 'country': 'Zimbabwe', 'country_code_3': 'ZWE'},
    {'tahun': 2023, 'tax_revenue_pct_gdp': 6.4392700195, 'country': 'Myanmar', 'country_code_3': 'MMR'},
    {'tahun': 2023, 'tax_revenue_pct_gdp': 6.4263100624, 'country': 'Micronesia', 'country_code_3': 'FSM'},
    {'tahun': 2023, 'tax_revenue_pct_gdp': 6.1963000298, 'country': 'Ethiopia', 'country_code_3': 'ETH'},
    {'tahun': 2023, 'tax_revenue_pct_gdp': 5.684800148, 'country': 'Lebanon', 'country_code_3': 'LBN'},
    {'tahun': 2023, 'tax_revenue_pct_gdp': 5.3715701103, 'country': 'Equatorial Guinea', 'country_code_3': 'GNQ'},
    {'tahun': 2023, 'tax_revenue_pct_gdp': 4.2168397903, 'country': 'Bahrain', 'country_code_3': 'BHR'},
    {'tahun': 2023, 'tax_revenue_pct_gdp': 1.4924399853, 'country': 'Kuwait', 'country_code_3': 'KWT'},
    {'tahun': 2023, 'tax_revenue_pct_gdp': 1.3445899487, 'country': 'Iraq', 'country_code_3': 'IRQ'},
    {'tahun': 2023, 'tax_revenue_pct_gdp': 0.5354459882, 'country': 'United Arab Emirates', 'country_code_3': 'ARE'},
    {'tahun': 2023, 'tax_revenue_pct_gdp': 0.0000787151, 'country': 'Somalia', 'country_code_3': 'SOM'}
]

import pandas as pd

# Create a DataFrame from the data
tax_revenue_df = pd.DataFrame(tax_revenue_pct_gdp_data)

# Display the first few rows of the DataFrame
display(tax_revenue_df.head())
# Out:
#    tahun  tax_revenue_pct_gdp     country country_code_3
# 0   2023           152.179993     Croatia            HRV
# 1   2023            44.346802       Nauru            NRU
# 2   2023            35.455601     Denmark            DNK
# 3   2023            32.480202  Seychelles            SYC
# 4   2023            32.390099     Lesotho            LSO

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Misalkan data diimpor dari BigQuery
data = {
    'country': ['Croatia', 'Nauru', 'Denmark', 'Seychelles', 'Lesotho', 'Indonesia', 'United States'],
    'tax_revenue_pct_gdp': [152.1799926758, 44.3468017578, 35.4556007385, 32.4802017212, 32.3900985718, 9.094039917, 11.2335996628]
}
df = pd.DataFrame(data)

# Bar plot untuk rasio pajak terhadap PDB
plt.figure(figsize=(10, 6))
sns.barplot(x='tax_revenue_pct_gdp', y='country', data=df, palette='viridis')
plt.title('Rasio Pendapatan Pajak terhadap PDB (2023)')
plt.xlabel('Persentase Pajak terhadap PDB (%)')
plt.ylabel('Negara')
plt.show()
# Out:
# /tmp/ipython-input-2848181423.py:14: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='tax_revenue_pct_gdp', y='country', data=df, palette='viridis')

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Misalkan data diimpor dari BigQuery
data = {
    'country': ['Croatia', 'Nauru', 'Denmark', 'Seychelles', 'Lesotho', 'Indonesia', 'United States'],
    'tax_revenue_pct_gdp': [152.1799926758, 44.3468017578, 35.4556007385, 32.4802017212, 32.3900985718, 9.094039917, 11.2335996628]
}
df = pd.DataFrame(data)

# Bar plot untuk rasio pajak terhadap PDB
plt.figure(figsize=(10, 6))
sns.barplot(x='tax_revenue_pct_gdp', y='country', data=df, palette='viridis')
plt.title('Rasio Pendapatan Pajak terhadap PDB (2023)')
plt.xlabel('Persentase Pajak terhadap PDB (%)')
plt.ylabel('Negara')
plt.show()
# Out:
# /tmp/ipython-input-2848181423.py:14: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='tax_revenue_pct_gdp', y='country', data=df, palette='viridis')
